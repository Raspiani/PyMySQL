# %% [markdown]
# ## PyMySQL - Python Database Connection
#
# Berikut ini cara menghubungkan database menggunakan pymysql
#
# ![image.png](attachment:image.png)
#
# Sumber :
# - https://www.youtube.com/watch?v=g60QghtJmjY&t=716s
# - https://www.youtube.com/watch?v=ryLsp6m1PnY

# %%
#memasukan modul yang digunakan
import pymysql

# %%
# Open database connection
db = pymysql.connect("localhost","testuser","test123","TESTDB" )

# prepare a cursor object using cursor() method
cursor = db.cursor()

# execute SQL query using execute() method.
cursor.execute("SELECT VERSION()")

# Fetch a single row using fetchone() method.
data = cursor.fetchone()
print ("Database version : %s " % data)

# disconnect from server
db.close()
# Out:
# Database version : 10.3.16-MariaDB

# %% [markdown]
#                     ##Semoga Bermanfaat
#                     ##Raspiani_
